# %%
class Card(str):
    def __new__(cls, value):
        obj = str.__new__(cls, value)
        color, number = obj.split('-')
        obj.color = color
        obj.number = int(number) if number else 0
        return obj

    def __init__(self, *args, **kwargs) -> None:
        print('init called', args, kwargs)
        self.color = self.color
        self.number = self.number
    
    def __repr__(self) -> str:
        return f'Card({self.color}-{self.number})'

Card('blue'), Card('red-10').number, Card('black-').color
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      14     def __repr__(self) -> str:
#      15         return f'Card({self.color}-{self.number})'
# ---> 17 Card('blue'), Card('red-10').number, Card('black-').color
#
# Cell In[8], line 6, in Card.__new__(cls, value)
#       4 color, *number = obj.split('-')
#       5 obj.color = color
# ----> 6 obj.number = int(number)
#       7 return obj
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
"""
Alex: yellow-5
Taylor2: black-14
Alex2: black-12
Taylor3: black-13
Alex3: green-5
Sam: yellow-13
Taylor: yellow-6
"""
from skullking.cards import Card
from skullking.game import Game
cards = [Card('yellow-5'), Card('black-14'), Card('black-12'), Card('black-13'), Card('green-13'), Card('yellow-13'), Card('yellow-6')]

Game.winning_card(cards)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 11
#       1 """
#       2 Alex: yellow-5
#       3 Taylor2: black-14
#    (...)      8 Taylor: yellow-6
#       9 """
#      10 from skullking.cards import Card
# ---> 11 from skullking.game import Game
#      12 cards = [Card('yellow-5'), Card('black-14'), Card('black-12'), Card('black-13'), Card('green-13'), Card('yellow-13'), Card('yellow-6')]
#      14 Game.winning_card(cards)
#
# File c:\Users\truma\Projects\Games-1\skullking\game.py:3
#       1 from  pandas import DataFrame, Categorical
#       2 from random import shuffle
# ----> 3 from cards import deck, Card
#       4 from numpy import array, nan
#       5 from typing import *
#
# ModuleNotFoundError: No module named 'cards'
